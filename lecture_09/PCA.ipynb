# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import numpy as np
import pandas as pd

# %%
X, y = make_blobs(n_samples=1000, n_features=10, centers=2)

# %%
X.shape
# Out:
# (1000, 10)

# %%
pca = PCA?

# %%
pca = PCA()

# %%
pca.fit_transform(X)

data = pca.transform(X)

# %%
data.shape
# Out:
# (1000, 10)

# %%
pca.components_
# Out:
# array([[-0.10166175,  0.18378716,  0.0161703 ,  0.02890936,  0.10868518,
#          0.0411707 ,  0.52898122, -0.41630383,  0.60642366,  0.34699104],
#        [-0.11783709, -0.34181981,  0.4579308 ,  0.02882283,  0.34971277,
#         -0.18368706, -0.42764387, -0.18054613, -0.03679582,  0.53467017],
#        [ 0.28469253, -0.02216133, -0.53144455, -0.14535796,  0.66309443,
#          0.06002391,  0.03413383, -0.2984989 , -0.28513879,  0.00537158],
#        [ 0.35904501, -0.32718374,  0.39953635, -0.52783822,  0.18056227,
#          0.26095004,  0.09551827,  0.08625947,  0.29777695, -0.34621063],
#        [-0.55195912, -0.28512406, -0.33080957, -0.08466729,  0.16743066,
#         -0.28817764, -0.23837399, -0.00091405,  0.42463562, -0.38629535],
#        [-0.30613112,  0.22365691,  0.32323706, -0.08658371,  0.41367576,
#         -0.38049699,  0.47266274,  0.32581924, -0.28638177, -0.12959177],
#        [ 0.09952586,  0.52883157,  0.23091017, -0.24306712, -0.09671398,
#         -0.33844663, -0.30528109, -0.53618322, -0.02532663, -0.30463175],
#        [ 0.08433167, -0.46879992,  0.17660953,  0.5000757 , -0.086578  ,
#         -0.13442924,  0.29821035, -0.44466536, -0.19894762, -0.374225  ],
#        [ 0.42518163, -0.23168129, -0.20947977, -0.21267428, -0.24834721,
#         -0.71803315,  0.14794832,  0.13913282,  0.08895611,  0.22366146],
#        [-0.41187907, -0.23960512, -0.07527234, -0.57405436, -0.34044855,
#          0.12981902,  0.2067942 , -0.29464428, -0.38788717,  0.15794603]])

# %%
plt.scatter(data[:, 0], data[:, 1], c = y)

# %%
mnist = pd.read_csv("../dataset/mnist_train.csv").values

# %%
X_train = mnist[:, 1:]
Y_train = mnist[:, 0]

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
x_data = pca.transform(X_train[:1000])

# %%
x_data.shape
# Out:
# (1000, 2)

# %%
plt.scatter(x_data[:,0], x_data[:, 1], c=Y_train[:1000], s = 4)
